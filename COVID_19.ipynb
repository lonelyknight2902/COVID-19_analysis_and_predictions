# %% [markdown]
# <a href="https://colab.research.google.com/github/lonelyknight2902/COVID-19_analysis_and_predictions/blob/main/COVID_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install statsmodels --upgrade
# Out:
# Requirement already up-to-date: statsmodels in /usr/local/lib/python3.7/dist-packages (0.12.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.19.5)
# Requirement already satisfied, skipping upgrade: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.1 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.1.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels) (1.15.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels) (2018.9)

# %% [markdown]
# # Import Library

# %%
#For tabular dataset
import pandas as pd
#Visualization libraries
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
#Tell Python to visualize in this window, not creating new one
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #**Task 1: Data Collection**

# %%
#Reading data
df_asia = pd.read_csv("/content/Asia.csv", parse_dates=['date'])
df_americas = pd.read_csv("/content/Americas.csv", parse_dates=['date'])
df_africa = pd.read_csv("/content/Africa.csv", parse_dates=['date'])
df_europe = pd.read_csv("/content/Europe.csv", parse_dates=['date'])

# %% [markdown]
# #**Task 2: Data Analysis**

# %% [markdown]
# ##**1.Asia**

# %%
countries = df_asia.country.unique()
df_asia.set_index(['country', 'date'], inplace=True)

# %% [markdown]
# ### July 2020 - December 2020

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == "India":
    continue
  sns.lineplot(data=df_asia.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 7 Asian countries from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0, 250000)
# Out:
# (0.0, 250000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_asia.xs("India")['cumulative_total_cases'])
plt.title("Cumulative total cases in India from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0, 1.2e7)
plt.yticks([0,0.2e7,0.4e7,0.6e7,0.8e7,1e7,1.2e7],['0','2M','4M','6M','8M','10M','12M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb06c49b10>,
#   <matplotlib.axis.YTick at 0x7fdb085617d0>,
#   <matplotlib.axis.YTick at 0x7fdb06c5d9d0>,
#   <matplotlib.axis.YTick at 0x7fdb069f8690>,
#   <matplotlib.axis.YTick at 0x7fdb069f8e90>,
#   <matplotlib.axis.YTick at 0x7fdb06a0e410>,
#   <matplotlib.axis.YTick at 0x7fdb069f8d90>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '2M'),
#   Text(0, 0, '4M'),
#   Text(0, 0, '6M'),
#   Text(0, 0, '8M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '12M')])

# %% [markdown]
# ### January 2021 - May 2021

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == "India":
    continue
  sns.lineplot(data=df_asia.xs(idx)['cumulative_total_cases'], label = idx)
plt.title("Cumulative total cases in 7 Asian countries from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0, 800000)
# Out:
# (0.0, 800000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_asia.xs("India")['cumulative_total_cases'])
plt.title("Cumulative total cases in India from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0, 3e7)
plt.yticks([0,0.5e7,1.0e7,1.5e7,2.0e7,2.5e7, 3e7],['0','5M','10M','15M','20M','25M','30M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb0687bf50>,
#   <matplotlib.axis.YTick at 0x7fdb0697c210>,
#   <matplotlib.axis.YTick at 0x7fdb06879850>,
#   <matplotlib.axis.YTick at 0x7fdb068a05d0>,
#   <matplotlib.axis.YTick at 0x7fdb068a0d50>,
#   <matplotlib.axis.YTick at 0x7fdb068b4350>,
#   <matplotlib.axis.YTick at 0x7fdb068a0e10>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '15M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '25M'),
#   Text(0, 0, '30M')])

# %% [markdown]
# ##**2.Europe**

# %%
countries = df_europe.country.unique()
df_europe.set_index(['country', 'date'], inplace=True)

# %% [markdown]
# ### July 2020 - December 2020

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  sns.lineplot(data=df_europe.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 9 European countries from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0, 4e6)
plt.yticks([0,0.5e6,1e6,1.5e6,2e6,2.5e6,3e6,3.5e6,4e6],['0','0.5M','1M','1.5M','2M','2.5M','3M','3.5M','4M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb0682f950>,
#   <matplotlib.axis.YTick at 0x7fdb068b4990>,
#   <matplotlib.axis.YTick at 0x7fdb06817750>,
#   <matplotlib.axis.YTick at 0x7fdb06955650>,
#   <matplotlib.axis.YTick at 0x7fdb0693d690>,
#   <matplotlib.axis.YTick at 0x7fdb0693d890>,
#   <matplotlib.axis.YTick at 0x7fdb06955290>,
#   <matplotlib.axis.YTick at 0x7fdb06968250>,
#   <matplotlib.axis.YTick at 0x7fdb06968750>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.5M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.5M'),
#   Text(0, 0, '2M'),
#   Text(0, 0, '2.5M'),
#   Text(0, 0, '3M'),
#   Text(0, 0, '3.5M'),
#   Text(0, 0, '4M')])

# %% [markdown]
# ### January 2021 - May 2021

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  sns.lineplot(data=df_europe.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 9 European countries from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0, 6e6)
plt.yticks([0,1e6,2e6,3e6,4e6,5e6,6e6],['0','1M','2M','3M','4M','5M','6M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb0671d190>,
#   <matplotlib.axis.YTick at 0x7fdb17e6d1d0>,
#   <matplotlib.axis.YTick at 0x7fdb066d5b10>,
#   <matplotlib.axis.YTick at 0x7fdb06676750>,
#   <matplotlib.axis.YTick at 0x7fdb06676910>,
#   <matplotlib.axis.YTick at 0x7fdb06676710>,
#   <matplotlib.axis.YTick at 0x7fdb066e7c90>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '2M'),
#   Text(0, 0, '3M'),
#   Text(0, 0, '4M'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '6M')])

# %% [markdown]
# ## **3. Americas**

# %%
countries = df_americas.country.unique()
df_americas.set_index(['country', 'date'], inplace=True)

# %% [markdown]
# ###July 2020 - December 2020

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == 'USA' or idx == 'Brazil':
    continue
  sns.lineplot(data=df_americas.xs(idx)['cumulative_total_cases'], label = idx)
plt.title("Cumulative total cases in 6 Americas countries from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0,1.8e6)
plt.yticks([0,0.2e6,0.4e6,0.6e6,0.8e6,1e6,1.2e6,1.4e6, 1.6e6,1.8e6],['0','0.2M','0.4M','0.6M','0.8M','1M','1.2M','1.4M','1.6M','1.8M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb066e43d0>,
#   <matplotlib.axis.YTick at 0x7fdb06a4d810>,
#   <matplotlib.axis.YTick at 0x7fdb065e2110>,
#   <matplotlib.axis.YTick at 0x7fdb0657e9d0>,
#   <matplotlib.axis.YTick at 0x7fdb0657ee10>,
#   <matplotlib.axis.YTick at 0x7fdb06577f90>,
#   <matplotlib.axis.YTick at 0x7fdb065851d0>,
#   <matplotlib.axis.YTick at 0x7fdb06585bd0>,
#   <matplotlib.axis.YTick at 0x7fdb0658e0d0>,
#   <matplotlib.axis.YTick at 0x7fdb069b2550>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.2M'),
#   Text(0, 0, '0.4M'),
#   Text(0, 0, '0.6M'),
#   Text(0, 0, '0.8M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.2M'),
#   Text(0, 0, '1.4M'),
#   Text(0, 0, '1.6M'),
#   Text(0, 0, '1.8M')])

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_americas.xs("USA")['cumulative_total_cases'])
plt.ylim(0,2.5e7)
plt.xlim("2020-07-01","2021-01-01")
plt.title("Cumulative total cases in the USA from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.yticks([0,0.5e7,1e7,1.5e7,2e7,2.5e7],['0','5M','10M','15M','20M','25M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb065de4d0>,
#   <matplotlib.axis.YTick at 0x7fdb0843a550>,
#   <matplotlib.axis.YTick at 0x7fdb0651ad10>,
#   <matplotlib.axis.YTick at 0x7fdb064b66d0>,
#   <matplotlib.axis.YTick at 0x7fdb064b6ed0>,
#   <matplotlib.axis.YTick at 0x7fdb064bc450>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '15M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '25M')])

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_americas.xs("Brazil")['cumulative_total_cases'])
plt.ylim(0,8e6)
plt.xlim("2020-07-01","2021-01-01")
plt.title("Cumulative total cases in Brazil from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.yticks([0,1e6,2e6,3e6,4e6,5e6,6e6,7e6,8e6],['0','1M','2M','3M','4M','5M','6M','7M','8M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb064e3f90>,
#   <matplotlib.axis.YTick at 0x7fdb064e3590>,
#   <matplotlib.axis.YTick at 0x7fdb06474d90>,
#   <matplotlib.axis.YTick at 0x7fdb0649ba10>,
#   <matplotlib.axis.YTick at 0x7fdb064a22d0>,
#   <matplotlib.axis.YTick at 0x7fdb0649b790>,
#   <matplotlib.axis.YTick at 0x7fdb06489790>,
#   <matplotlib.axis.YTick at 0x7fdb064a2090>,
#   <matplotlib.axis.YTick at 0x7fdb064a2c90>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '2M'),
#   Text(0, 0, '3M'),
#   Text(0, 0, '4M'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '6M'),
#   Text(0, 0, '7M'),
#   Text(0, 0, '8M')])

# %% [markdown]
# ###January 2021 - May 2021

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == 'USA' or idx == 'Brazil':
    continue
  sns.lineplot(data=df_americas.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 6 Americas countries from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0,4e6)
plt.yticks([0,0.5e6,1e6,1.5e6,2e6,2.5e6,3e6,3.5e6,4e6],['0','0.5M','1M','1.5M','2M','2.5M','3M','3.5M','4M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb06459b50>,
#   <matplotlib.axis.YTick at 0x7fdb06459390>,
#   <matplotlib.axis.YTick at 0x7fdb0646b950>,
#   <matplotlib.axis.YTick at 0x7fdb064145d0>,
#   <matplotlib.axis.YTick at 0x7fdb06414d50>,
#   <matplotlib.axis.YTick at 0x7fdb06414650>,
#   <matplotlib.axis.YTick at 0x7fdb0640e050>,
#   <matplotlib.axis.YTick at 0x7fdb0641b410>,
#   <matplotlib.axis.YTick at 0x7fdb0641b950>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.5M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.5M'),
#   Text(0, 0, '2M'),
#   Text(0, 0, '2.5M'),
#   Text(0, 0, '3M'),
#   Text(0, 0, '3.5M'),
#   Text(0, 0, '4M')])

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_americas.xs("Brazil")['cumulative_total_cases'], markers='o')
plt.ylim(0.6e7,1.8e7)
plt.xlim("2021-01-01","2021-06-01")
plt.title("Cumulative total cases in Brazil from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.yticks([0.6e7,0.8e7,1e7,1.2e7,1.4e7,1.6e7,1.8e7],['6M','8M','10M','12M','14M','16M','18M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb0641bc50>,
#   <matplotlib.axis.YTick at 0x7fdb067e8790>,
#   <matplotlib.axis.YTick at 0x7fdb06333910>,
#   <matplotlib.axis.YTick at 0x7fdb0633d5d0>,
#   <matplotlib.axis.YTick at 0x7fdb0633dc50>,
#   <matplotlib.axis.YTick at 0x7fdb06347210>,
#   <matplotlib.axis.YTick at 0x7fdb0633dd10>],
#  [Text(0, 0, '6M'),
#   Text(0, 0, '8M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '12M'),
#   Text(0, 0, '14M'),
#   Text(0, 0, '16M'),
#   Text(0, 0, '18M')])

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_americas.xs("USA")['cumulative_total_cases'], markers='o')
plt.ylim(2e7,3.5e7)
plt.xlim("2021-01-01","2021-06-01")
plt.title("Cumulative total cases in the USA from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.yticks([2e7,2.2e7,2.4e7,2.6e7,2.8e7,3e7,3.2e7,3.4e7],['20M','22M','24M','26M','28M','30M','32M','34M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb06356450>,
#   <matplotlib.axis.YTick at 0x7fdb063564d0>,
#   <matplotlib.axis.YTick at 0x7fdb062f9990>,
#   <matplotlib.axis.YTick at 0x7fdb0631d690>,
#   <matplotlib.axis.YTick at 0x7fdb0631de10>,
#   <matplotlib.axis.YTick at 0x7fdb0631d7d0>,
#   <matplotlib.axis.YTick at 0x7fdb06317cd0>,
#   <matplotlib.axis.YTick at 0x7fdb06317d50>],
#  [Text(0, 0, '20M'),
#   Text(0, 0, '22M'),
#   Text(0, 0, '24M'),
#   Text(0, 0, '26M'),
#   Text(0, 0, '28M'),
#   Text(0, 0, '30M'),
#   Text(0, 0, '32M'),
#   Text(0, 0, '34M')])

# %% [markdown]
# ##**4.Africa**

# %%
countries = df_africa.country.unique()
df_africa.set_index(['country', 'date'], inplace=True)

# %% [markdown]
# ### July 2020 - December 2020

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == 'South Africa' or idx == 'Egypt':
    continue
  sns.lineplot(data=df_africa.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 6 African countries from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0,40000)
# Out:
# (0.0, 40000.0)

# %% [markdown]
# The graph demonstrates the daily cumulative incidence in 6 African countries in the period from July to December 2020. Overall, the number of cumulative cases in all countries included had experienced a gradual rise in last half of the year.
#
# We can clearly see that Zambia, Zimbabwe, Niger and Congo followed a similar upward trend from july 2020 until the begin of december 2020. However, in the next stage, they seperated into 2 groups: Zambia and Zimbabwe which rose rapidly in the figures, Niger and Congo which still increased but slowly.
#
# There were remarkable points about the statistic of Uganda and Madagascar. First, while the amount of cumulative cases in Uganda started at approximately 900 which was the second lowest figues, it witnessed a significant growth upto over 14,000 cases at the end of the period. In contrast, Madagascar possessed the highest number of cases in the begin of the period, almost 2,500. But it grew slightly, not until October 2020, the figure seem to remain steadily through the period.

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_africa.xs('Egypt')['cumulative_total_cases'])
plt.title("Cumulative total cases in Egypt from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(60000,150000)
# Out:
# (60000.0, 150000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_africa.xs("South Africa")['cumulative_total_cases'])
plt.title("Cumulative total cases in South Africa from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0, 1.2e6)
plt.yticks([0,0.2e6,0.4e6,0.6e6,0.8e6,1e6,1.2e6],['0','0.2M','0.4M','0.6M','0.8M','1M','1.2M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb061e29d0>,
#   <matplotlib.axis.YTick at 0x7fdb06210ed0>,
#   <matplotlib.axis.YTick at 0x7fdb061842d0>,
#   <matplotlib.axis.YTick at 0x7fdb061a2d90>,
#   <matplotlib.axis.YTick at 0x7fdb061aa710>,
#   <matplotlib.axis.YTick at 0x7fdb061a2850>,
#   <matplotlib.axis.YTick at 0x7fdb061aa190>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.2M'),
#   Text(0, 0, '0.4M'),
#   Text(0, 0, '0.6M'),
#   Text(0, 0, '0.8M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.2M')])

# %% [markdown]
# Since Egypt and Africa figures is very high so we decided to draw it in seperate graph.
#
# Both of them share the same upward trend.

# %% [markdown]
# ### January 2021 - May 2021

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == 'South Africa' or idx == 'Egypt':
    continue
  sns.lineplot(data=df_africa.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 6 African countries from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0,100000)
# Out:
# (0.0, 100000.0)

# %% [markdown]
# The graph demonstrates the daily cumulative incidence in 6 African countries in the period from January to May 2021. Overall, the number of cumulative cases in all countries included was continuously rising, in comparison with the figures from July to December last year.
#
# The most noticeable is Uganda. While having a sharp growth in 2020, the amount of cases in Uganda seem to be controlled and leveled off. Moreover, Zambia had a big hit which made it be the highest cumulative cases country, ended up with around 92,000 cases.
#
# Congo and Niger successfully remained stably through the whole time. Besides, Zimbabwe and Madagascar had some slight changes but they are not considerable.

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_africa.xs('Egypt')['cumulative_total_cases'])
plt.title("Cumulative total cases in Egypt from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(125000,275000)
# Out:
# (125000.0, 275000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_africa.xs("South Africa")['cumulative_total_cases'], markers=True)
plt.title("Cumulative total cases in South Africa from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(1e6, 1.8e6)
plt.yticks([1e6,1.1e6,1.2e6,1.3e6,1.4e6,1.5e6,1.6e6,1.7e6,1.8e6],['1M','1.1M','1.2M','1.3M','1.4M','1.5M','1.6M','1.7M','1.8M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7fdb0605d4d0>,
#   <matplotlib.axis.YTick at 0x7fdb06272550>,
#   <matplotlib.axis.YTick at 0x7fdb05ff39d0>,
#   <matplotlib.axis.YTick at 0x7fdb0601d650>,
#   <matplotlib.axis.YTick at 0x7fdb0601de50>,
#   <matplotlib.axis.YTick at 0x7fdb0601d7d0>,
#   <matplotlib.axis.YTick at 0x7fdb06017610>,
#   <matplotlib.axis.YTick at 0x7fdb06023410>,
#   <matplotlib.axis.YTick at 0x7fdb060238d0>],
#  [Text(0, 0, '1M'),
#   Text(0, 0, '1.1M'),
#   Text(0, 0, '1.2M'),
#   Text(0, 0, '1.3M'),
#   Text(0, 0, '1.4M'),
#   Text(0, 0, '1.5M'),
#   Text(0, 0, '1.6M'),
#   Text(0, 0, '1.7M'),
#   Text(0, 0, '1.8M')])

# %% [markdown]
# # Task 3: Model prediction

# %% [markdown]
# ##**3.1 AutoRegression**

# %% [markdown]
# Autoregression is a time series model that uses observations from previous time steps as input to a regression equation to predict the value at the next time step.

# %%
from statsmodels.tsa.ar_model import AutoReg
from math import sqrt
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ###**3.1.a Global prediction**

# %%
global_pdf = pd.read_csv('/content/worldometer_coronavirus_daily_data.csv', parse_dates=['date'])
cumulative_total_cases = global_pdf.groupby('date').sum()['cumulative_total_cases'].reset_index()
cumulative_total_cases.columns = ['date','cumulative_total_cases']
cumulative_total_cases['date'] = pd.to_datetime(cumulative_total_cases['date'])

# %%
series = cumulative_total_cases.set_index('date')['cumulative_total_cases']
X = series.loc['2020-07-01':'2021-05-31'].values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series.loc['2020-07-01':'2021-05-31'], label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Global cumulative total cases and prediction from July 2020 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 2.5e8)
plt.yticks([0,0.5e8,1e8,1.5e8,2e8,2.5e8], ['0','50M','100M','150M','200M','250M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7fdb05fda810>,
#   <matplotlib.axis.YTick at 0x7fdb0602b690>,
#   <matplotlib.axis.YTick at 0x7fdb05f8c690>,
#   <matplotlib.axis.YTick at 0x7fdb05f903d0>,
#   <matplotlib.axis.YTick at 0x7fdb05f8c650>,
#   <matplotlib.axis.YTick at 0x7fdb05f7e790>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '50M'),
#   Text(0, 0, '100M'),
#   Text(0, 0, '150M'),
#   Text(0, 0, '200M'),
#   Text(0, 0, '250M')])

# %% [markdown]
# ###**3.1.b Countries with the highest number of infections**

# %% [markdown]
# ####**USA**

# %%
series = df_americas.xs('USA').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in the US from January 2021 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 4e7)
plt.yticks([0,0.5e7,1e7,1.5e7,2e7,2.5e7,3e7,3.5e7,4e7],['0','5M','10M','15M','20M','25M','30M','35M','40M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7fdb05f60510>,
#   <matplotlib.axis.YTick at 0x7fdb05f52b90>,
#   <matplotlib.axis.YTick at 0x7fdb05f70310>,
#   <matplotlib.axis.YTick at 0x7fdb05f16090>,
#   <matplotlib.axis.YTick at 0x7fdb05f10910>,
#   <matplotlib.axis.YTick at 0x7fdb05f07050>,
#   <matplotlib.axis.YTick at 0x7fdb05f16a50>,
#   <matplotlib.axis.YTick at 0x7fdb05f16e50>,
#   <matplotlib.axis.YTick at 0x7fdb05f1f3d0>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '15M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '25M'),
#   Text(0, 0, '30M'),
#   Text(0, 0, '35M'),
#   Text(0, 0, '40M')])

# %% [markdown]
# ####**Brazil**

# %%
series = df_americas.xs('Brazil').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in Brazil from January 2021 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 2.5e7)
plt.yticks([0,0.5e7,1e7,1.5e7,2e7,2.5e7],['0','5M','10M','15M','20M','25M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7fdb05ed5d10>,
#   <matplotlib.axis.YTick at 0x7fdb05ed5a10>,
#   <matplotlib.axis.YTick at 0x7fdb05ee6b10>,
#   <matplotlib.axis.YTick at 0x7fdb05e90790>,
#   <matplotlib.axis.YTick at 0x7fdb05e90950>,
#   <matplotlib.axis.YTick at 0x7fdb05e90d90>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '15M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '25M')])

# %% [markdown]
# ####**India**

# %%
series = df_asia.xs('India').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in India from January 2021 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 8e7)
plt.yticks([0,1e7,2e7,3e7,4e7,5e7,6e7,7e7,8e7],['0','10M','20M','30M','40M','50M','60M','70M','80M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7fdb05e47bd0>,
#   <matplotlib.axis.YTick at 0x7fdb05e59c90>,
#   <matplotlib.axis.YTick at 0x7fdb05e5ba10>,
#   <matplotlib.axis.YTick at 0x7fdb05e12690>,
#   <matplotlib.axis.YTick at 0x7fdb05e12e90>,
#   <matplotlib.axis.YTick at 0x7fdb05e12310>,
#   <matplotlib.axis.YTick at 0x7fdb05e0a610>,
#   <matplotlib.axis.YTick at 0x7fdb05e19550>,
#   <matplotlib.axis.YTick at 0x7fdb05e37690>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '30M'),
#   Text(0, 0, '40M'),
#   Text(0, 0, '50M'),
#   Text(0, 0, '60M'),
#   Text(0, 0, '70M'),
#   Text(0, 0, '80M')])

# %% [markdown]
# ###**3.1.c Some Asian countries**

# %% [markdown]
# ####**Viet Nam**

# %%
series = df_asia.xs('Viet Nam').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in Viet Nam from July 2020 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 325000)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# (0.0, 325000.0)

# %% [markdown]
# #### **Japan**

# %%
series = df_asia.xs('Japan').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in Japan from July 2020 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 1.2e6)
plt.yticks([0,0.2e6,0.4e6,0.6e6,0.8e6,1e6,1.2e6],['0','0.2M','0.4M','0.6M','0.8M','1M','1.2M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7fdb06d91f10>,
#   <matplotlib.axis.YTick at 0x7fdb06c537d0>,
#   <matplotlib.axis.YTick at 0x7fdb069a00d0>,
#   <matplotlib.axis.YTick at 0x7fdb05dab550>,
#   <matplotlib.axis.YTick at 0x7fdb05d7fbd0>,
#   <matplotlib.axis.YTick at 0x7fdb05d7fd50>,
#   <matplotlib.axis.YTick at 0x7fdb05d7f7d0>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.2M'),
#   Text(0, 0, '0.4M'),
#   Text(0, 0, '0.6M'),
#   Text(0, 0, '0.8M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.2M')])

# %% [markdown]
# ####**South Korea**

# %%
series = df_asia.xs('South Korea').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in South Korea from July 2020 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 225000)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# (0.0, 225000.0)

# %% [markdown]
# ##**3.2 Prophet**

# %% [markdown]
# Prophet is a procedure for forecasting time series data based on **an additive model** where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.

# %%
from fbprophet import Prophet

# %% [markdown]
# **3.2.a Global prediction**

# %%
global_pdf = pd.read_csv('/content/worldometer_coronavirus_daily_data.csv', parse_dates=['date'])
cumulative_total_cases = global_pdf.groupby('date').sum()['cumulative_total_cases'].reset_index()
cumulative_total_cases.columns = ['ds','y']
cumulative_total_cases['ds'] = pd.to_datetime(cumulative_total_cases['ds'])
cumulative_total_cases
# Out:
#             ds            y
# 0   2020-01-22        571.0
# 1   2020-01-23        830.0
# 2   2020-01-24       1287.0
# 3   2020-01-25       1975.0
# 4   2020-01-26       2744.0
# ..         ...          ...
# 521 2021-06-26  181548720.0
# 522 2021-06-27  181870218.0
# 523 2021-06-28  182188731.0
# 524 2021-06-29  182570601.0
# 525 2021-06-30  182961399.0
#
# [526 rows x 2 columns]

# %%
m = Prophet(interval_width=0.95)
m.fit(cumulative_total_cases)
future = m.make_future_dataframe(periods=92)
forecast = m.predict(future)
confirmed_forecast_plot = m.plot(forecast, xlabel = "Date",ylabel = 'Cumulative Total Cases', figsize=(20,10))
plt.title("Global cumulative total cases and prediction from July 2020 to August 2021")
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Text(0.5, 1.0, 'Global cumulative total cases and prediction from July 2020 to August 2021')

# %% [markdown]
# ###**3.2.b Countries with the highest number of infections**

# %%
#predict data frame = pdf
pdf = df_americas.xs('USA').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#rename for prophet
m = Prophet()
m.fit(pdf)
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
confirmed_forecast_plot = m.plot(forecast, xlabel = "Date",ylabel = 'Cumulative Total Cases', figsize=(20,10))
plt.title("Cumulative total cases and prediction in the USA from July 2020 to August 2021")
#print(confirmed_forecast_plot)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Text(0.5, 1.0, 'Cumulative total cases and prediction in the USA from July 2020 to August 2021')

# %%
#predict data frame = pdf
pdf = df_americas.xs('Brazil').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#rename for prophet
m = Prophet()
m.fit(pdf)
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
confirmed_forecast_plot = m.plot(forecast, xlabel = "Date",ylabel = 'Cumulative Total Cases', figsize=(20,10))
plt.title("Cumulative total cases and prediction in Brazil from July 2020 to August 2021")
#print(confirmed_forecast_plot)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Text(0.5, 1.0, 'Cumulative total cases and prediction in Brazil from July 2020 to August 2021')

# %%
#predict data frame = pdf
pdf = df_asia.xs('India').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#rename for prophet
m = Prophet()
m.fit(pdf)
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
confirmed_forecast_plot = m.plot(forecast, xlabel = "Date",ylabel = 'Cumulative Total Cases', figsize=(20,10))
plt.title("Cumulative total cases and prediction in India from July 2020 to August 2021")
#print(confirmed_forecast_plot)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Text(0.5, 1.0, 'Cumulative total cases and prediction in India from July 2020 to August 2021')

# %% [markdown]
# ###**3.2.c Some Asian countries prediction**

# %%
#predict data frame = pdf
pdf = df_asia.xs('Viet Nam').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#rename for prophet
m = Prophet()
m.fit(pdf)
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
confirmed_forecast_plot = m.plot(forecast, xlabel = "Date",ylabel = 'Cumulative Total Cases', figsize=(20,10))
plt.title("Cumulative total cases and prediction in Viet Nam from July 2020 to August 2021")
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Text(0.5, 1.0, 'Cumulative total cases and prediction in Viet Nam from July 2020 to August 2021')

# %%
#predict data frame = pdf
pdf = df_asia.xs('Japan').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#rename for prophet
m = Prophet()
m.fit(pdf)
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
confirmed_forecast_plot = m.plot(forecast, xlabel = "Date",ylabel = 'Cumulative Total Cases', figsize=(20,10))
plt.title("Cumulative total cases and prediction in Japan from July 2020 to August 2021")
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Text(0.5, 1.0, 'Cumulative total cases and prediction in Japan from July 2020 to August 2021')

# %%
#predict data frame = pdf
pdf = df_asia.xs('South Korea').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#rename for prophet
m = Prophet()
m.fit(pdf)
future = m.make_future_dataframe(periods=90)
forecast = m.predict(future)
confirmed_forecast_plot = m.plot(forecast, xlabel = "Date",ylabel = 'Cumulative Total Cases', figsize=(20,10))
plt.title("Cumulative total cases and prediction in South Korea from July 2020 to August 2021")
#print(confirmed_forecast_plot)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Text(0.5, 1.0, 'Cumulative total cases and prediction in South Korea from July 2020 to August 2021')

# %% [markdown]
# # **Model Analysis**

# %% [markdown]
# ## Auto Regression

# %%
data = pd.read_csv('/content/worldometer_coronavirus_daily_data.csv', index_col='date', parse_dates=['date'])

# %% [markdown]
# Viet Nam

# %%
test = data[data.country == 'Viet Nam'].loc['2021-06-01':'2021-07-01']['cumulative_total_cases']
series = df_asia.xs('Viet Nam').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+30-1, dynamic=False)
rmse_ar = sqrt(mean_squared_error(test.values, predictions))
#train prophet
X = df_asia.xs('Viet Nam').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
X = X.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
m = Prophet()
m.fit(X)
future = pd.DataFrame({ 'ds': pd.date_range('2021-06-01', periods=30, freq='D')})
forecast = m.predict(future)
rmse_pht = sqrt(mean_squared_error(test, forecast.yhat))
print('Auto regression test RMSE: %.3f' % rmse_ar)
print('Prophet test RMSE: %.3f' % rmse_pht)
# plot results
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=30, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
forecast = forecast.rename(columns={'ds':'date'})
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=test, label='Actual')
sns.lineplot(data=df, x='date', y='Predicted', label='Auto Regression')
sns.lineplot(data=forecast, x = 'date', y = 'yhat', label='Prophet')
plt.xlim('2021-06-01','2021-07-01')
title = "Actual vs predicted cumulative total cases in Viet Nam in June 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
#predict data frame
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Auto regression test RMSE: 3748.065
# Prophet test RMSE: 6683.344
# Text(0, 0.5, 'Cumulative total cases')

# %%
test = data[data.country == 'USA'].loc['2021-06-01':'2021-07-01']['cumulative_total_cases']
series = df_americas.xs('USA').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+30-1, dynamic=False)
rmse_ar = sqrt(mean_squared_error(test.values, predictions))
#train prophet
X = df_americas.xs('USA').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
X = X.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
m = Prophet()
m.fit(X)
future = pd.DataFrame({ 'ds': pd.date_range('2021-06-01', periods=30, freq='D')})
forecast = m.predict(future)
rmse_pht = sqrt(mean_squared_error(test, forecast.yhat))
print('Auto regression test RMSE: %.3f' % rmse_ar)
print('Prophet test RMSE: %.3f' % rmse_pht)
# plot results
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=30, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
forecast = forecast.rename(columns={'ds':'date'})
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=test, label='Actual')
sns.lineplot(data=df, x='date', y='Predicted', label='Auto Regression')
sns.lineplot(data=forecast, x = 'date', y = 'yhat', label='Prophet')
title = "Actual vs predicted cumulative total cases in the USA in June 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2021-06-01','2021-06-30')
plt.ylim(3.4e7, 3.625e7)
plt.yticks([3.4e7, 3.45e7, 3.5e7, 3.55e7, 3.6e7], ['34M', '34.5M','35M', '35.5M', '36M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Auto regression test RMSE: 87081.528
# Prophet test RMSE: 1077928.459
# ([<matplotlib.axis.YTick at 0x7fdb05d4c610>,
#   <matplotlib.axis.YTick at 0x7fdb06272d50>,
#   <matplotlib.axis.YTick at 0x7fdb068b6f90>,
#   <matplotlib.axis.YTick at 0x7fdb05d389d0>,
#   <matplotlib.axis.YTick at 0x7fdb05d38b90>],
#  [Text(0, 0, '34M'),
#   Text(0, 0, '34.5M'),
#   Text(0, 0, '35M'),
#   Text(0, 0, '35.5M'),
#   Text(0, 0, '36M')])

# %%
test = data[data.country == 'Brazil'].loc['2021-06-01':'2021-07-01']['cumulative_total_cases']
series = df_americas.xs('Brazil').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+30-1, dynamic=False)
rmse_ar = sqrt(mean_squared_error(test.values, predictions))
#train prophet
X = df_americas.xs('Brazil').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
X = X.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
m = Prophet()
m.fit(X)
future = pd.DataFrame({ 'ds': pd.date_range('2021-06-01', periods=30, freq='D')})
forecast = m.predict(future)
rmse_pht = sqrt(mean_squared_error(test, forecast.yhat))
print('Auto regression test RMSE: %.3f' % rmse_ar)
print('Prophet test RMSE: %.3f' % rmse_pht)
# plot results
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=30, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
forecast = forecast.rename(columns={'ds':'date'})
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=test, label='Actual')
sns.lineplot(data=df, x='date', y='Predicted', label='Auto Regression')
sns.lineplot(data=forecast, x = 'date', y = 'yhat', label='Prophet')
title = "Actual vs predicted cumulative total cases in Brazil in June 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2021-06-01','2021-07-01')
plt.ylim(1.65e7, 1.9e7)
plt.yticks([1.65e7, 1.7e7, 1.75e7, 1.8e7, 1.85e7, 1.9e7], ['16.5M', '17M','17.5M', '18M', '18.5M', '19M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Auto regression test RMSE: 31348.340
# Prophet test RMSE: 77781.324
# ([<matplotlib.axis.YTick at 0x7fdb06922b10>,
#   <matplotlib.axis.YTick at 0x7fdb0626a950>,
#   <matplotlib.axis.YTick at 0x7fdb0629b2d0>,
#   <matplotlib.axis.YTick at 0x7fdb05cc6090>,
#   <matplotlib.axis.YTick at 0x7fdb0621f390>,
#   <matplotlib.axis.YTick at 0x7fdb0621f7d0>],
#  [Text(0, 0, '16.5M'),
#   Text(0, 0, '17M'),
#   Text(0, 0, '17.5M'),
#   Text(0, 0, '18M'),
#   Text(0, 0, '18.5M'),
#   Text(0, 0, '19M')])

# %%
test = data[data.country == 'India'].loc['2021-06-01':'2021-07-01']['cumulative_total_cases']
series = df_asia.xs('India').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+30-1, dynamic=False)
rmse_ar = sqrt(mean_squared_error(test.values, predictions))
#train prophet
X = df_asia.xs('India').reset_index().drop(['daily_new_cases', 'active_cases','cumulative_total_deaths','daily_new_deaths'], axis=1)
X = X.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
m = Prophet()
m.fit(X)
future = pd.DataFrame({ 'ds': pd.date_range('2021-06-01', periods=30, freq='D')})
forecast = m.predict(future)
rmse_pht = sqrt(mean_squared_error(test, forecast.yhat))
print('Auto regression test RMSE: %.3f' % rmse_ar)
print('Prophet test RMSE: %.3f' % rmse_pht)
# plot results
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=30, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
forecast = forecast.rename(columns={'ds':'date'})
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=test, label='Actual')
sns.lineplot(data=df, x='date', y='Predicted', label='Auto Regression', palette=['red'])
sns.lineplot(data=forecast, x = 'date', y = 'yhat', label='Prophet')
title = "Actual vs predicted cumulative total cases in India in June 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2021-06-01','2021-07-01')
plt.ylim(2.8e7, 3.7e7)
plt.yticks([2.8e7, 2.9e7, 3e7, 3.1e7, 3.2e7, 3.3e7, 3.4e7, 3.5e7, 3.6e7, 3.7e7], ['28M', '29M','30M', '31M', '32M', '33M','34M','35M','36M','37M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Auto regression test RMSE: 2522106.866
# Prophet test RMSE: 2983959.586
# ([<matplotlib.axis.YTick at 0x7fdb06105390>,
#   <matplotlib.axis.YTick at 0x7fdb068f5750>,
#   <matplotlib.axis.YTick at 0x7fdb062dc1d0>,
#   <matplotlib.axis.YTick at 0x7fdb05d38e90>,
#   <matplotlib.axis.YTick at 0x7fdb05cbf590>,
#   <matplotlib.axis.YTick at 0x7fdb05cbf1d0>,
#   <matplotlib.axis.YTick at 0x7fdb05cef250>,
#   <matplotlib.axis.YTick at 0x7fdb05b17b10>,
#   <matplotlib.axis.YTick at 0x7fdb05cef2d0>,
#   <matplotlib.axis.YTick at 0x7fdb05b0fed0>],
#  [Text(0, 0, '28M'),
#   Text(0, 0, '29M'),
#   Text(0, 0, '30M'),
#   Text(0, 0, '31M'),
#   Text(0, 0, '32M'),
#   Text(0, 0, '33M'),
#   Text(0, 0, '34M'),
#   Text(0, 0, '35M'),
#   Text(0, 0, '36M'),
#   Text(0, 0, '37M')])
