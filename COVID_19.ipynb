# %% [markdown]
# <a href="https://colab.research.google.com/github/lonelyknight2902/COVID-19_analysis_and_predictions/blob/main/COVID_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install statsmodels --upgrade
# Out:
# Requirement already up-to-date: statsmodels in /usr/local/lib/python3.7/dist-packages (0.12.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.19.5)
# Requirement already satisfied, skipping upgrade: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.1.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.1 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied, skipping upgrade: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels) (1.15.0)

# %% [markdown]
# # Import Library

# %%
#For tabular dataset
import pandas as pd
#Visualization libraries
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
#Tell Python to visualize in this window, not creating new one
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #**Task 1: Data Collection**

# %%
#Reading data
df_asia = pd.read_csv("/content/Asia.csv", parse_dates=['date'])
df_americas = pd.read_csv("/content/Americas.csv", parse_dates=['date'])
df_africa = pd.read_csv("/content/Africa.csv", parse_dates=['date'])
df_europe = pd.read_csv("/content/Europe.csv", parse_dates=['date'])

# %% [markdown]
# #**Task 2: Data Analysis**

# %% [markdown]
# ##**1.Asia**

# %%
countries = df_asia.country.unique()
df_asia.set_index(['country', 'date'], inplace=True)

# %% [markdown]
# ### July 2020 - December 2020

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == "India":
    continue
  sns.lineplot(data=df_asia.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 7 Asian countries from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0, 250000)
# Out:
# (0.0, 250000.0)

# %%
#Since India figures is very high so we decided to draw it in seperate graph
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_asia.xs("India")['cumulative_total_cases'])
plt.title("Cumulative total cases in India from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0, 1.2e7)
plt.yticks([0,0.2e7,0.4e7,0.6e7,0.8e7,1e7,1.2e7],['0','0.2M','0.4M','0.6M','0.8M','1M','1.2M'])
#plt.yticks([0,0.5e7,1.0e7,1.5e7,2.0e7,2.5e7, 3e7],['0','5M','10M','15M','20M','25M','30M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f8331efb910>,
#   <matplotlib.axis.YTick at 0x7f83418e7510>,
#   <matplotlib.axis.YTick at 0x7f83324b6110>,
#   <matplotlib.axis.YTick at 0x7f8331d5b4d0>,
#   <matplotlib.axis.YTick at 0x7f8331d5b7d0>,
#   <matplotlib.axis.YTick at 0x7f8331d5bd10>,
#   <matplotlib.axis.YTick at 0x7f83315fd350>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.2M'),
#   Text(0, 0, '0.4M'),
#   Text(0, 0, '0.6M'),
#   Text(0, 0, '0.8M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.2M')])

# %% [markdown]
# ### January 2021 - May 2021

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == "India":
    continue
  sns.lineplot(data=df_asia.xs(idx)['cumulative_total_cases'], label = idx)
plt.title("Cumulative total cases in 7 Asian countries from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0, 800000)
# Out:
# (0.0, 800000.0)

# %%
#Since India figures is very high so we decided to draw it in seperate graph
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_asia.xs("India")['cumulative_total_cases'])
plt.title("Cumulative total cases in India from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0, 3e7)
plt.yticks([0,0.5e7,1.0e7,1.5e7,2.0e7,2.5e7, 3e7],['0','5M','10M','15M','20M','25M','30M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f83314e64d0>,
#   <matplotlib.axis.YTick at 0x7f8331d1d3d0>,
#   <matplotlib.axis.YTick at 0x7f83314f3210>,
#   <matplotlib.axis.YTick at 0x7f833148c2d0>,
#   <matplotlib.axis.YTick at 0x7f833148c910>,
#   <matplotlib.axis.YTick at 0x7f83314fbf90>,
#   <matplotlib.axis.YTick at 0x7f8331492050>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '15M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '25M'),
#   Text(0, 0, '30M')])

# %% [markdown]
# ##**2.Europe**

# %%
countries = df_europe.country.unique()
df_europe.set_index(['country', 'date'], inplace=True)

# %% [markdown]
# ### July 2020 - December 2020

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  sns.lineplot(data=df_europe.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 9 European countries from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0, 4e6)
plt.yticks([0,0.5e6,1e6,1.5e6,2e6,2.5e6,3e6,3.5e6,4e6],['0','0.5M','1M','1.5M','2M','2.5M','3M','3.5M','4M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f83314be3d0>,
#   <matplotlib.axis.YTick at 0x7f83314bdbd0>,
#   <matplotlib.axis.YTick at 0x7f833149b550>,
#   <matplotlib.axis.YTick at 0x7f8331473fd0>,
#   <matplotlib.axis.YTick at 0x7f8331473b10>,
#   <matplotlib.axis.YTick at 0x7f833146a790>,
#   <matplotlib.axis.YTick at 0x7f833147c110>,
#   <matplotlib.axis.YTick at 0x7f833147cc10>,
#   <matplotlib.axis.YTick at 0x7f83314850d0>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.5M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.5M'),
#   Text(0, 0, '2M'),
#   Text(0, 0, '2.5M'),
#   Text(0, 0, '3M'),
#   Text(0, 0, '3.5M'),
#   Text(0, 0, '4M')])

# %% [markdown]
# The plot show the daily cumulative incidence for 9 European countries over the period from July to December 2020. All cumulative incidence appears to show an exponential trend, increasing slowly in July before growing rapidly.
#
# Italy and France's cumulative total cases increase most rapidly from October to the end of November - approxiamately 1.3 million new cases in Italy and 2 million in France during this period.
#
# Russia with the highest amount of cumulative cases among 9 countries also show an exponential trend - increase from 600 thousand up to approximately 5 million by the end of 2020.
#
# Portugal and Hungary share the same trend with the least number of cumulative cases compared to other countries in the dataset with less than 500 thousand total cases in each countries.

# %% [markdown]
# ### January 2021 - May 2021

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  sns.lineplot(data=df_europe.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 9 European countries from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0, 6e6)
plt.yticks([0,1e6,2e6,3e6,4e6,5e6,6e6],['0','1M','2M','3M','4M','5M','6M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f83315744d0>,
#   <matplotlib.axis.YTick at 0x7f8331e09f50>,
#   <matplotlib.axis.YTick at 0x7f8331355e90>,
#   <matplotlib.axis.YTick at 0x7f8331388dd0>,
#   <matplotlib.axis.YTick at 0x7f833130f710>,
#   <matplotlib.axis.YTick at 0x7f833130fc50>,
#   <matplotlib.axis.YTick at 0x7f833130fb10>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '2M'),
#   Text(0, 0, '3M'),
#   Text(0, 0, '4M'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '6M')])

# %% [markdown]
# The plot show the daily cumulative incidence for 9 European countries over the period from January to May 2021. Compared to the previous plot, the increase of cumulative cases starts to slow down in some countries while others are still showing an exponential trend.
#
# Russia, UK, Spain and Portugal all saw a slow increase in new cases after January. In the case of Portugal, the number of new cases daily has dropped below a thousand and remained stable since March, showing a linear trend throughout the next period.
#
# On the other hand, France and Turkey still maintain an exponential trend. Cumulative cases of both countries continue to increase significantly up to 3 million, making France and Turkey the two leading countries in total cases by the end of May.

# %% [markdown]
# ## **3. Americas**

# %%
countries = df_americas.country.unique()
df_americas.set_index(['country', 'date'], inplace=True)

# %% [markdown]
# ###July 2020 - December 2020

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == 'USA':
    continue
  sns.lineplot(data=df_americas.xs(idx)['cumulative_total_cases'], label = idx)
plt.title("Cumulative total cases in 7 Americas countries from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0,0.8e7)
plt.yticks([0,1e6,2e6,3e6,4e6,5e6,6e6,7e6, 8e6],['0','1M','2M','3M','4M','5M','6M','7M','8M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f83312c2910>,
#   <matplotlib.axis.YTick at 0x7f83313746d0>,
#   <matplotlib.axis.YTick at 0x7f8331355490>,
#   <matplotlib.axis.YTick at 0x7f8331217550>,
#   <matplotlib.axis.YTick at 0x7f8331210890>,
#   <matplotlib.axis.YTick at 0x7f8331285cd0>,
#   <matplotlib.axis.YTick at 0x7f8331217dd0>,
#   <matplotlib.axis.YTick at 0x7f8331220090>,
#   <matplotlib.axis.YTick at 0x7f8331220690>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '2M'),
#   Text(0, 0, '3M'),
#   Text(0, 0, '4M'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '6M'),
#   Text(0, 0, '7M'),
#   Text(0, 0, '8M')])

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_americas.xs("USA")['cumulative_total_cases'], markers='o')
plt.ylim(0,2.5e7)
plt.xlim("2020-07-01","2021-01-01")
plt.title("Cumulative total cases in the USA from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.yticks([0,0.5e7,1e7,1.5e7,2e7,2.5e7],['0','5M','10M','15M','20M','25M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f8330849190>,
#   <matplotlib.axis.YTick at 0x7f83308ebf90>,
#   <matplotlib.axis.YTick at 0x7f83307e4810>,
#   <matplotlib.axis.YTick at 0x7f8330809410>,
#   <matplotlib.axis.YTick at 0x7f8330809c50>,
#   <matplotlib.axis.YTick at 0x7f8330803710>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '15M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '25M')])

# %% [markdown]
# ###January 2021 - May 2021

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == 'USA':
    continue
  sns.lineplot(data=df_americas.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 7 Americas countries from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0,1.75e7)
plt.yticks([0,0.25e7,0.5e7,0.75e7,1e7,1.25e7,1.5e7,1.75e7],['0','0.25M','0.5M','0.75M','1M','1.25M','1.5M','1.75M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f833110ee90>,
#   <matplotlib.axis.YTick at 0x7f833110e490>,
#   <matplotlib.axis.YTick at 0x7f833116cf10>,
#   <matplotlib.axis.YTick at 0x7f83310cb7d0>,
#   <matplotlib.axis.YTick at 0x7f83310cbd90>,
#   <matplotlib.axis.YTick at 0x7f83310cb610>,
#   <matplotlib.axis.YTick at 0x7f83310d4150>,
#   <matplotlib.axis.YTick at 0x7f83310d4710>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.25M'),
#   Text(0, 0, '0.5M'),
#   Text(0, 0, '0.75M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.25M'),
#   Text(0, 0, '1.5M'),
#   Text(0, 0, '1.75M')])

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_americas.xs("USA")['cumulative_total_cases'], markers='o')
plt.ylim(2e7,3.5e7)
plt.xlim("2021-01-01","2021-06-01")
plt.title("Cumulative total cases in the USA from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.yticks([2e7,2.2e7,2.4e7,2.6e7,2.8e7,3e7,3.2e7,3.4e7],['20M','22M','24M','26M','28M','30M','32M','34M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f8331071d90>,
#   <matplotlib.axis.YTick at 0x7f8331c81410>,
#   <matplotlib.axis.YTick at 0x7f83310fbc50>,
#   <matplotlib.axis.YTick at 0x7f8331019590>,
#   <matplotlib.axis.YTick at 0x7f8331019e10>,
#   <matplotlib.axis.YTick at 0x7f8331019690>,
#   <matplotlib.axis.YTick at 0x7f8331014bd0>,
#   <matplotlib.axis.YTick at 0x7f833101f650>],
#  [Text(0, 0, '20M'),
#   Text(0, 0, '22M'),
#   Text(0, 0, '24M'),
#   Text(0, 0, '26M'),
#   Text(0, 0, '28M'),
#   Text(0, 0, '30M'),
#   Text(0, 0, '32M'),
#   Text(0, 0, '34M')])

# %% [markdown]
# ##**4.Africa**

# %% [markdown]
# ### July 2020 - December 2020

# %%
countries = df_africa.country.unique()
df_africa.set_index(['country', 'date'], inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == 'South Africa' or idx == 'Egypt':
    continue
  sns.lineplot(data=df_africa.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 6 African countries from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0,40000)
# Out:
# (0.0, 40000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_africa.xs('Egypt')['cumulative_total_cases'])
plt.title("Cumulative total cases in Egypt from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(60000,150000)
# Out:
# (60000.0, 150000.0)

# %% [markdown]
# The graph demonstrates the daily cumulative incidence in 7 African countries in the period from July to December 2020. Overall, the number of cumulative cases experienced a gradual increase,

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_africa.xs("South Africa")['cumulative_total_cases'])
plt.title("Cumulative total cases in South Africa from July 2020 to December 2020")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2020-07-01","2021-01-01")
plt.ylim(0, 1.2e6)
plt.yticks([0,0.2e6,0.4e6,0.6e6,0.8e6,1e6,1.2e6],['0','0.2M','0.4M','0.6M','0.8M','1M','1.2M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f8330e1d510>,
#   <matplotlib.axis.YTick at 0x7f8330fb0950>,
#   <matplotlib.axis.YTick at 0x7f8330f78050>,
#   <matplotlib.axis.YTick at 0x7f8330f57950>,
#   <matplotlib.axis.YTick at 0x7f8330f57e10>,
#   <matplotlib.axis.YTick at 0x7f8330f54650>,
#   <matplotlib.axis.YTick at 0x7f8330f5b210>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.2M'),
#   Text(0, 0, '0.4M'),
#   Text(0, 0, '0.6M'),
#   Text(0, 0, '0.8M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.2M')])

# %% [markdown]
# ### January 2021 - May 2021

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  if idx == 'South Africa' or idx == 'Egypt':
    continue
  sns.lineplot(data=df_africa.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 6 African countries from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(0,100000)
# Out:
# (0.0, 100000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_africa.xs('Egypt')['cumulative_total_cases'])
plt.title("Cumulative total cases in Egypt from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(125000,275000)
# Out:
# (125000.0, 275000.0)

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=df_africa.xs("South Africa")['cumulative_total_cases'], markers=True)
plt.title("Cumulative total cases in South Africa from January 2021 to May 2021")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim("2021-01-01","2021-06-01")
plt.ylim(1e6, 1.8e6)
plt.yticks([1e6,1.1e6,1.2e6,1.3e6,1.4e6,1.5e6,1.6e6,1.7e6,1.8e6],['1M','1.1M','1.2M','1.3M','1.4M','1.5M','1.6M','1.7M','1.8M'])
# Out:
# ([<matplotlib.axis.YTick at 0x7f8330a64e90>,
#   <matplotlib.axis.YTick at 0x7f8330ab4350>,
#   <matplotlib.axis.YTick at 0x7f83309db1d0>,
#   <matplotlib.axis.YTick at 0x7f83309f8fd0>,
#   <matplotlib.axis.YTick at 0x7f83309f8690>,
#   <matplotlib.axis.YTick at 0x7f83309ecb50>,
#   <matplotlib.axis.YTick at 0x7f8330a00210>,
#   <matplotlib.axis.YTick at 0x7f8330a00c10>,
#   <matplotlib.axis.YTick at 0x7f8330a080d0>],
#  [Text(0, 0, '1M'),
#   Text(0, 0, '1.1M'),
#   Text(0, 0, '1.2M'),
#   Text(0, 0, '1.3M'),
#   Text(0, 0, '1.4M'),
#   Text(0, 0, '1.5M'),
#   Text(0, 0, '1.6M'),
#   Text(0, 0, '1.7M'),
#   Text(0, 0, '1.8M')])

# %% [markdown]
# # Task 3: Model prediction

# %% [markdown]
# Overall, our tasks are to focus on three main sections:
#
# 1.   Global
# *   Asia, Americas ( Prophet - Additive Model )
# *   Europe, Africa ( AutoRegression )
# 2.   3 countries with the highest number of cases
# *   USA
# *   India
# *   Brazil
# 3.   Some Asian countries

# %% [markdown]
# ##**3.1 AutoRegression**

# %% [markdown]
# Autoregression is a time series model that uses observations from previous time steps as input to a regression equation to predict the value at the next time step.

# %%
from statsmodels.tsa.ar_model import AutoReg
from math import sqrt
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ###**3.1.a Global prediction**

# %%
global_pdf = pd.read_csv('/content/worldometer_coronavirus_daily_data.csv', parse_dates=['date'])
cumulative_total_cases = global_pdf.groupby('date').sum()['cumulative_total_cases'].reset_index()
cumulative_total_cases.columns = ['date','cumulative_total_cases']
cumulative_total_cases['date'] = pd.to_datetime(cumulative_total_cases['date'])

# %%
series = cumulative_total_cases.set_index('date')['cumulative_total_cases']
X = series.loc['2020-07-01':'2021-05-31'].values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series.loc['2020-07-01':'2021-05-31'], label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Global cumulative total cases and prediction from July 2020 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 2.5e8)
plt.yticks([0,0.5e8,1e8,1.5e8,2e8,2.5e8], ['0','50M','100M','150M','200M','250M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7f832c08d550>,
#   <matplotlib.axis.YTick at 0x7f832c018cd0>,
#   <matplotlib.axis.YTick at 0x7f832c02e390>,
#   <matplotlib.axis.YTick at 0x7f832bfd64d0>,
#   <matplotlib.axis.YTick at 0x7f832c04f390>,
#   <matplotlib.axis.YTick at 0x7f832c048090>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '50M'),
#   Text(0, 0, '100M'),
#   Text(0, 0, '150M'),
#   Text(0, 0, '200M'),
#   Text(0, 0, '250M')])

# %% [markdown]
# ###**3.1.b Countries with the highest number of infections**

# %% [markdown]
# ####**USA**

# %%
series = df_americas.xs('USA').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in the US from January 2021 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 4e7)
plt.yticks([0,0.5e7,1e7,1.5e7,2e7,2.5e7,3e7,3.5e7,4e7],['0','5M','10M','15M','20M','25M','30M','35M','40M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7f832bfa0090>,
#   <matplotlib.axis.YTick at 0x7f832c013710>,
#   <matplotlib.axis.YTick at 0x7f832bfa1e90>,
#   <matplotlib.axis.YTick at 0x7f832bfd1a90>,
#   <matplotlib.axis.YTick at 0x7f832bfd1a50>,
#   <matplotlib.axis.YTick at 0x7f832bfcadd0>,
#   <matplotlib.axis.YTick at 0x7f832bf580d0>,
#   <matplotlib.axis.YTick at 0x7f832bf58950>,
#   <matplotlib.axis.YTick at 0x7f832bf58e90>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '15M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '25M'),
#   Text(0, 0, '30M'),
#   Text(0, 0, '35M'),
#   Text(0, 0, '40M')])

# %% [markdown]
# ####**Brazil**

# %%
series = df_americas.xs('Brazil').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in Brazil from January 2021 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 2.5e7)
plt.yticks([0,0.5e7,1e7,1.5e7,2e7,2.5e7],['0','5M','10M','15M','20M','25M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7f832bf8cc50>,
#   <matplotlib.axis.YTick at 0x7f832bf8c950>,
#   <matplotlib.axis.YTick at 0x7f832bf36450>,
#   <matplotlib.axis.YTick at 0x7f832bedb4d0>,
#   <matplotlib.axis.YTick at 0x7f832bf54750>,
#   <matplotlib.axis.YTick at 0x7f832bf4c250>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '5M'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '15M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '25M')])

# %% [markdown]
# ####**India**

# %%
series = df_asia.xs('India').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in India from January 2021 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 8e7)
plt.yticks([0,1e7,2e7,3e7,4e7,5e7,6e7,7e7,8e7],['0','10M','20M','30M','40M','50M','60M','70M','80M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7f832c17de50>,
#   <matplotlib.axis.YTick at 0x7f832c190250>,
#   <matplotlib.axis.YTick at 0x7f832c12b7d0>,
#   <matplotlib.axis.YTick at 0x7f832c0d7550>,
#   <matplotlib.axis.YTick at 0x7f832c151690>,
#   <matplotlib.axis.YTick at 0x7f832c0d7ad0>,
#   <matplotlib.axis.YTick at 0x7f832c0d76d0>,
#   <matplotlib.axis.YTick at 0x7f832c0e1310>,
#   <matplotlib.axis.YTick at 0x7f832c27d610>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '10M'),
#   Text(0, 0, '20M'),
#   Text(0, 0, '30M'),
#   Text(0, 0, '40M'),
#   Text(0, 0, '50M'),
#   Text(0, 0, '60M'),
#   Text(0, 0, '70M'),
#   Text(0, 0, '80M')])

# %% [markdown]
# ###**3.1.c Some Asian countries**

# %% [markdown]
# ####**Viet Nam**

# %%
series = df_asia.xs('Viet Nam').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in Viet Nam from July 2020 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 325000)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# (0.0, 325000.0)

# %% [markdown]
# #### **Japan**

# %%
series = df_asia.xs('Japan').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in Japan from July 2020 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 1.2e6)
plt.yticks([0,0.2e6,0.4e6,0.6e6,0.8e6,1e6,1.2e6],['0','0.2M','0.4M','0.6M','0.8M','1M','1.2M'])
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# ([<matplotlib.axis.YTick at 0x7f8335f0dbd0>,
#   <matplotlib.axis.YTick at 0x7f8330c50e50>,
#   <matplotlib.axis.YTick at 0x7f8330949e10>,
#   <matplotlib.axis.YTick at 0x7f83309c3b50>,
#   <matplotlib.axis.YTick at 0x7f83309c38d0>,
#   <matplotlib.axis.YTick at 0x7f8330d71590>,
#   <matplotlib.axis.YTick at 0x7f8330d71c50>],
#  [Text(0, 0, '0'),
#   Text(0, 0, '0.2M'),
#   Text(0, 0, '0.4M'),
#   Text(0, 0, '0.6M'),
#   Text(0, 0, '0.8M'),
#   Text(0, 0, '1M'),
#   Text(0, 0, '1.2M')])

# %% [markdown]
# ####**South Korea**

# %%
series = df_asia.xs('South Korea').reset_index().set_index('date')['cumulative_total_cases']
X = series.values
# train autoregression
model = AutoReg(X, lags=29)
model_fit = model.fit()
#print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(X), end=len(X)+92-1, dynamic=False)
# plot results
#pyplot.plot(test)
#pyplot.plot(predictions, color='red')
#pyplot.show()
df = pd.DataFrame({ 'date': pd.date_range('2021-06-01', periods=92, freq='D'), 'Predicted' : predictions})
df = df.set_index('date')
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.lineplot(data=series, label='Past')
sns.lineplot(data=df, palette=['red'])
title = "Cumulative total cases and prediction in South Korea from July 2020 to August 2021"
plt.title(title)
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
plt.xlim('2020-07-01','2021-09-01')
plt.ylim(0, 225000)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/ar_model.py:252: FutureWarning:
#
# The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
# (0.0, 225000.0)

# %% [markdown]
# ##**3.2 Prophet**

# %% [markdown]
# Prophet is a procedure for forecasting time series data based on **an additive model** where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.

# %%
from fbprophet import Prophet

# %% [markdown]
# **3.2.a Global prediction**

# %%
global_pdf = pd.read_csv('/content/worldometer_coronavirus_daily_data.csv', parse_dates=['date'])
cumulative_total_cases = global_pdf.groupby('date').sum()['cumulative_total_cases'].reset_index()
cumulative_total_cases.columns = ['ds','y']
cumulative_total_cases['ds'] = pd.to_datetime(cumulative_total_cases['ds'])
cumulative_total_cases
# Out:
#             ds            y
# 0   2020-01-22        571.0
# 1   2020-01-23        830.0
# 2   2020-01-24       1287.0
# 3   2020-01-25       1975.0
# 4   2020-01-26       2744.0
# ..         ...          ...
# 521 2021-06-26  181548720.0
# 522 2021-06-27  181870218.0
# 523 2021-06-28  182188731.0
# 524 2021-06-29  182570601.0
# 525 2021-06-30  182961399.0
#
# [526 rows x 2 columns]

# %%
m = Prophet(interval_width=0.95)
m.fit(cumulative_total_cases)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
confirmed_forecast_plot = m.plot(forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# **3.2.b Some Asian countries prediction**

# %%
#predict data frame = pdf
pdf = pd.read_csv("/content/prophet_data/Africa-prophet.csv", parse_dates=['date'])
pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#rename for prophet
asia_countries_grouped = pdf.groupby('country')
for g in asia_countries_grouped.groups:
    group = asia_countries_grouped.get_group(g)
    m = Prophet()
    m.fit(group)
    future = m.make_future_dataframe(periods=90)
    forecast = m.predict(future)
    print(g)
    confirmed_forecast_plot = m.plot(forecast, xlabel = f"Cumulative total cases and prediction in {g} from January 2021 to September 2021",ylabel = 'Cumulative Total Cases')
    #print(confirmed_forecast_plot)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-50d1f7f72236> in <module>()
#       1
#       2 #predict data frame = pdf
# ----> 3 pdf = pd.read_csv("/content/prophet_data/Africa-prophet.csv", parse_dates=['date'])
#       4 pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#       5 #rename for prophet
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/prophet_data/Africa-prophet.csv'

# %% [markdown]
# **3.2.c Some American countries prediction**

# %%
#predict data frame = pdf
pdf = pd.read_csv("/content/prophet_data/Americas-prophet.csv", parse_dates=['date'])
pdf = pdf.rename(columns={'date': 'ds', 'cumulative_total_cases':'y'})
#rename for prophet
asia_countries_grouped = pdf.groupby('country')
for g in asia_countries_grouped.groups:
    group = asia_countries_grouped.get_group(g)
    m = Prophet()
    m.fit(group)
    future = m.make_future_dataframe(periods=90)
    forecast = m.predict(future)
    print(g)
    confirmed_forecast_plot = m.plot(forecast, xlabel = f"Cumulative total cases and prediction in {g} from January 2021 to September 2021",ylabel = 'Cumulative Total Cases')
    #print(confirmed_forecast_plot)
