# %% [markdown]
# <a href="https://colab.research.google.com/github/lonelyknight2902/COVID-19_analysis_and_predictions/blob/main/COVID_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data_path = "/content/Europe.csv"
data = pd.read_csv(data_path, parse_dates=['date'])
countries = data.country.unique()

# %%
data.set_index(['country', 'date'], inplace=True)
data
# Out:
#                     cumulative_total_cases  ...  daily_new_deaths
# country date                                ...
# Italy   2020-07-01                  240781  ...                21
#         2020-07-02                  240982  ...                30
#         2020-07-03                  241205  ...                15
#         2020-07-04                  241440  ...                21
#         2020-07-05                  241632  ...                 7
# ...                                    ...  ...               ...
# Hungary 2021-05-27                  803119  ...                32
#         2021-05-28                  803567  ...                28
#         2021-05-29                  804032  ...                27
#         2021-05-30                  804382  ...                19
#         2021-05-31                  804538  ...                 5
#
# [3015 rows x 5 columns]

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
for idx in countries:
  sns.lineplot(data=data.xs(idx)['cumulative_total_cases'], label = idx, markers=True)
plt.title("Cumulative total cases in 9 European countries")
plt.xlabel("Date")
plt.ylabel("Cumulative total cases")
# Out:
# Text(0, 0.5, 'Cumulative total cases')
